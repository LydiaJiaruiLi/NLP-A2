# %% [markdown]
# BERT-large-uncased

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# !pwd
# %cd gdrive/My\ Drive/Colab\ Notebooks/CSI5386/A2/Assignment2
# Out:
# /content
# /content/gdrive/My Drive/Colab Notebooks/CSI5386/A2/Assignment2

# %%
# !pip install transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 5.8 MB 4.7 MB/s
# ...
#      |████████████████████████████████| 182 kB 75.1 MB/s
# ...
#      |████████████████████████████████| 7.6 MB 82.7 MB/s
# ...

# %%
path = "gdrive/My\ Drive/Colab\ Notebooks/CSI5382/A2/Assignment2"

# %%
output_dir = './train_models/bert-large-uncased'
model_type = 'bert'
model_path = 'bert-large-uncased'

train_file = './data/train_split1.json'

# %%
command = 'CUDA_VISIBLE_DEVICES=0,1 python train.py \
        --output_dir {} \
        --model_type {} \
        --model_name_or_path {} \
        --train_file {} \
        --predict_file ./data/test.json \
        --do_train \
        --version_2_with_negative \
        --learning_rate 1e-4 \
        --num_train_epochs 4 \
        --per_gpu_eval_batch_size=70  \
        --per_gpu_train_batch_size=20 \
        --max_seq_length 512 \
        --max_answer_length 512 \
        --doc_stride 256 \
        --save_steps 1000 \
        --n_best_size 20 \
        --overwrite_output_dir'.format(output_dir, model_type, model_path, train_file)

# %%
with open('run.sh', 'w+') as f:
    f.write(command)

# %%
# !chmod 755 run.sh

# %%
# !./run.sh
# Out:
# 2022-12-01 21:00:57.691329: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:654] 2022-12-01 21:01:01,498 >> loading configuration file config.json from cache at /root/.cache/huggingface/hub/models--bert-large-uncased/snapshots/80792f8e8216b29f3c846b653a0ff0a37c210431/config.json
# [INFO|configuration_utils.py:706] 2022-12-01 21:01:01,499 >> Model config BertConfig {
#   "_name_or_path": "bert-large-uncased",
#   "architectures": [
#     "BertForMaskedLM"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
# ...

# %%
output_dir = './train_models/bert-large-uncased'
model_type = 'bert'
model_path = './models/bert-large-uncased'

train_file = './data/train_split2.json'

command = 'CUDA_VISIBLE_DEVICES=0,1 python train.py \
        --output_dir {} \
        --model_type {} \
        --model_name_or_path {} \
        --train_file {} \
        --predict_file ./data/test.json \
        --do_train \
        --version_2_with_negative \
        --learning_rate 1e-4 \
        --num_train_epochs 4 \
        --per_gpu_eval_batch_size=70  \
        --per_gpu_train_batch_size=20 \
        --max_seq_length 512 \
        --max_answer_length 512 \
        --doc_stride 256 \
        --save_steps 1000 \
        --n_best_size 20 \
        --overwrite_output_dir'.format(output_dir, model_type, model_path, train_file)

with open('run.sh', 'w+') as f:
    f.write(command)

# !chmod 755 run.sh
# !./run.sh
# Out:
# 2022-12-02 01:35:07.675568: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:652] 2022-12-02 01:35:11,163 >> loading configuration file ./models/bert-large-uncased/config.json
# [INFO|configuration_utils.py:706] 2022-12-02 01:35:11,164 >> Model config BertConfig {
#   "_name_or_path": "./models/bert-large-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
# ...

# %%
output_dir = './train_models/bert-large-uncased'
model_type = 'bert'
model_path = './models/bert-large-uncased'

train_file = './data/train_split3.json'

command = 'CUDA_VISIBLE_DEVICES=0,1 python train.py \
        --output_dir {} \
        --model_type {} \
        --model_name_or_path {} \
        --train_file {} \
        --predict_file ./data/test.json \
        --do_train \
        --version_2_with_negative \
        --learning_rate 1e-4 \
        --num_train_epochs 4 \
        --per_gpu_eval_batch_size=70  \
        --per_gpu_train_batch_size=20 \
        --max_seq_length 512 \
        --max_answer_length 512 \
        --doc_stride 256 \
        --save_steps 1000 \
        --n_best_size 20 \
        --overwrite_output_dir'.format(output_dir, model_type, model_path, train_file)

with open('run.sh', 'w+') as f:
    f.write(command)

# !chmod 755 run.sh
# !./run.sh
# Out:
# 2022-12-02 02:14:58.617376: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:652] 2022-12-02 02:15:02,167 >> loading configuration file ./models/bert-large-uncased/config.json
# [INFO|configuration_utils.py:706] 2022-12-02 02:15:02,168 >> Model config BertConfig {
#   "_name_or_path": "./models/bert-large-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
# ...

# %%
output_dir = './train_models/bert-large-uncased'
model_type = 'bert'
model_path = './models/bert-large-uncased'

train_file = './data/train_split4.json'

command = 'CUDA_VISIBLE_DEVICES=0,1 python train.py \
        --output_dir {} \
        --model_type {} \
        --model_name_or_path {} \
        --train_file {} \
        --predict_file ./data/test.json \
        --do_train \
        --version_2_with_negative \
        --learning_rate 1e-4 \
        --num_train_epochs 4 \
        --per_gpu_eval_batch_size=70  \
        --per_gpu_train_batch_size=20 \
        --max_seq_length 512 \
        --max_answer_length 512 \
        --doc_stride 256 \
        --save_steps 1000 \
        --n_best_size 20 \
        --overwrite_output_dir'.format(output_dir, model_type, model_path, train_file)

with open('run.sh', 'w+') as f:
    f.write(command)

# !chmod 755 run.sh
# !./run.sh
# Out:
# 2022-12-02 03:29:15.260453: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:652] 2022-12-02 03:29:19,020 >> loading configuration file ./models/bert-large-uncased/config.json
# [INFO|configuration_utils.py:706] 2022-12-02 03:29:19,021 >> Model config BertConfig {
#   "_name_or_path": "./models/bert-large-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
# ...

# %%
output_dir = './train_models/bert-large-uncased'
model_type = 'bert'
model_path = './models/bert-large-uncased'

train_file = './data/train_separate_questions.json'
command = 'CUDA_VISIBLE_DEVICES=0,1 python train.py \
        --output_dir {} \
        --model_type {} \
        --model_name_or_path {} \
        --train_file {} \
        --predict_file ./data/test.json \
        --do_eval \
        --version_2_with_negative \
        --learning_rate 1e-4 \
        --num_train_epochs 4 \
        --per_gpu_eval_batch_size=40  \
        --per_gpu_train_batch_size=20 \
        --max_seq_length 512 \
        --max_answer_length 512 \
        --doc_stride 256 \
        --save_steps 1000 \
        --n_best_size 20 \
        --overwrite_output_dir'.format(output_dir, model_type, model_path, train_file)
with open('run.sh', 'w+') as f:
    f.write(command)

# !chmod 755 run.sh
# !./run.sh
# Out:
# 2022-12-02 04:07:44.231806: I tensorflow/core/util/util.cc:169] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# WARNING:__main__:Process rank: -1, device: cuda, n_gpu: 1, distributed training: False, 16-bits training: False
# [INFO|configuration_utils.py:652] 2022-12-02 04:07:47,776 >> loading configuration file ./models/bert-large-uncased/config.json
# [INFO|configuration_utils.py:706] 2022-12-02 04:07:47,777 >> Model config BertConfig {
#   "_name_or_path": "./models/bert-large-uncased",
#   "architectures": [
#     "BertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "classifier_dropout": null,
#   "gradient_checkpointing": false,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 1024,
#   "initializer_range": 0.02,
#   "intermediate_size": 4096,
# ...

# %%
# !python3 evaluate.py \
        --test_json_path ./data/test.json \
        --save_dir ./results \
        --model_path ./train_models/bert-large-uncased
# Out:
# AUPR: 0.287, Precision at 80% Recall: 0.000, Precision at 90% Recall: 0.000
